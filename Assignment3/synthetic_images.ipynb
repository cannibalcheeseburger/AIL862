# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import os
from tqdm.auto import tqdm

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# %%
model_id = "CompVis/stable-diffusion-v1-4"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)

# %%
classes = [  "church","cassette player","golf ball",]

# %%
prompts = {
    "cassette player": "A high-quality photograph of a vintage cassette player",
    "golf ball": "A detailed close-up image of a golf ball",
    "church": "A clear picture of a beautiful church exterior"
}

# %%
base_dir = "./data/synthetic_imagenette"
os.makedirs(base_dir, exist_ok=True)

# %%
num_images_per_class = 1000

# %%
#for class_name in classes:
#    class_dir = os.path.join(base_dir, class_name)
#    os.makedirs(class_dir, exist_ok=True)#######

#    print(f"Generating images for class: {class_name}")
#    for i in tqdm(range(num_images_per_class)):
#        image = pipe(prompt).images[0]
#        image.save(f"{class_dir}/{class_name.replace(' ', '_')}_{i:03d}.png")

# %%
batch_size = 100
from collections import deque

# %%
class_queue = deque(classes)

while True:
    all_complete = True

    for _ in range(len(classes)):
        class_name = class_queue[0]
        class_dir = os.path.join(base_dir, class_name)
        os.makedirs(class_dir, exist_ok=True)

        # Count existing images
        existing_images = len([f for f in os.listdir(class_dir) if f.endswith('.png')])
        images_to_generate = max(0, num_images_per_class - existing_images)

        if images_to_generate > 0:
            all_complete = False
            prompt = prompts[class_name]

            print(f"\nGenerating images for class: {class_name}")
            print(f"Existing images: {existing_images}")
            print(f"Images to generate: {images_to_generate}")

            # Generate one batch
            batch_size = min(batch_size, images_to_generate)
            batch_images = []
            for _ in tqdm(range(batch_size), desc=f"Batch for {class_name}"):
                image = pipe(prompt).images[0]
                batch_images.append(image)

            for i, image in enumerate(batch_images):
                image_index = existing_images + i
                image.save(f"{class_dir}/{class_name.replace(' ', '_')}_{image_index:04d}.png")

            print(f"Completed batch for {class_name}")

        # Rotate to the next class
        class_queue.rotate(-1)

    if all_complete:
        break

print("Finished generating all images for all classes")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Completed batch for church
#
# Generating images for class: golf ball
# Existing images: 779
# Images to generate: 221
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Completed batch for golf ball
#
# Generating images for class: church
# Existing images: 929
# Images to generate: 71
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Completed batch for church
#
# Generating images for class: golf ball
# Existing images: 878
# Images to generate: 122
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Completed batch for golf ball
#
# Generating images for class: golf ball
# Existing images: 949
# Images to generate: 51
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# Completed batch for golf ball
# Finished generating all images for all classes

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
for i, class_name in enumerate(classes):
    img_path = os.path.join(base_dir, class_name, f"{class_name.replace(' ', '_')}_000.png")
    img = Image.open(img_path)
    plt.subplot(1, 3, i+1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(15, 5))
#       4 for i, class_name in enumerate(classes):
#
# ModuleNotFoundError: No module named 'matplotlib'
